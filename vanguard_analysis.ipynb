# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_demo = pd.read_csv('data/df_final_demo.txt')

df_web_1 = pd.read_csv('data/df_final_web_data_pt_1.txt')

df_web_2 = pd.read_csv('data/df_final_web_data_pt_2.txt')

df_experiment = pd.read_csv('data/df_final_experiment_clients.txt')

# %%
df_web = pd.concat([df_web_1, df_web_2])

# %% [markdown]
# # DATA 1

# %%
df_demo.head()
# Out:
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0

# %%
df_demo.shape
# Out:
# (70609, 9)

# %%
df_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70609 non-null  int64
#  1   clnt_tenure_yr    70595 non-null  float64
#  2   clnt_tenure_mnth  70595 non-null  float64
#  3   clnt_age          70594 non-null  float64
#  4   gendr             70595 non-null  object
#  5   num_accts         70595 non-null  float64
#  6   bal               70595 non-null  float64
#  7   calls_6_mnth      70595 non-null  float64
#  8   logons_6_mnth     70595 non-null  float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 4.8+ MB

# %%
df_demo.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  7.060900e+04    70595.000000      70595.000000  70594.000000
# mean   5.004992e+06       12.052950        150.659367     46.442240
# std    2.877278e+06        6.871819         82.089854     15.591273
# min    1.690000e+02        2.000000         33.000000     13.500000
# 25%    2.519329e+06        6.000000         82.000000     32.500000
# 50%    5.016978e+06       11.000000        136.000000     47.000000
# 75%    7.483085e+06       16.000000        192.000000     59.000000
# max    9.999839e+06       62.000000        749.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  70595.000000  7.059500e+04  70595.000000   70595.000000
# mean       2.255528  1.474452e+05      3.382478       5.566740
# std        0.534997  3.015087e+05      2.236580       2.353286
# min        1.000000  1.378942e+04      0.000000       1.000000
# ...

# %%
df_demo.isnull().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df_demo.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # DATA 2 Y 3

# %%
df_web.shape
# Out:
# (755405, 5)

# %%
df_web.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 755405 entries, 0 to 412263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     755405 non-null  int64
#  1   visitor_id    755405 non-null  object
#  2   visit_id      755405 non-null  object
#  3   process_step  755405 non-null  object
#  4   date_time     755405 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 34.6+ MB

# %%
df_web.describe()
# Out:
#           client_id
# count  7.554050e+05
# mean   5.013632e+06
# std    2.879152e+06
# min    1.690000e+02
# 25%    2.519882e+06
# 50%    5.033441e+06
# 75%    7.496063e+06
# max    9.999875e+06

# %%
df_web.isnull().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_web.duplicated().sum()
# Out:
# np.int64(10764)

# %% [markdown]
# # DATA 3

# %%
df_experiment.shape
# Out:
# (70609, 2)

# %%
df_experiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70609 entries, 0 to 70608
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  70609 non-null  int64
#  1   Variation  50500 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB

# %%
df_experiment.isnull().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
df_experiment.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Variables

# %%
df_experiment['Variation'].value_counts()
# Out:
# Variation
# Test       26968
# Control    23532
# Name: count, dtype: int64

# %%
df_web['process_step'].value_counts()
# Out:
# process_step
# start      243945
# step_1     163193
# step_2     133062
# step_3     112242
# confirm    102963
# Name: count, dtype: int64

# %%
df_demo['clnt_age'].describe()
# Out:
# count    70594.000000
# mean        46.442240
# std         15.591273
# min         13.500000
# 25%         32.500000
# 50%         47.000000
# 75%         59.000000
# max         96.000000
# Name: clnt_age, dtype: float64

# %%
df_demo['gendr'].value_counts()
# Out:
# gendr
# U    24122
# M    23724
# F    22746
# X        3
# Name: count, dtype: int64

# %%
df_demo['bal'].describe()
# Out:
# count    7.059500e+04
# mean     1.474452e+05
# std      3.015087e+05
# min      1.378942e+04
# 25%      3.734683e+04
# 50%      6.333290e+04
# 75%      1.375449e+05
# max      1.632004e+07
# Name: bal, dtype: float64

# %%
df_demo['bal'].describe().apply(lambda x: format(x, '.2f'))
# Out:
# count       70595.00
# mean       147445.24
# std        301508.71
# min         13789.42
# 25%         37346.83
# 50%         63332.90
# 75%        137544.90
# max      16320040.15
# Name: bal, dtype: object

# %%
sns.countplot(
    data=df_web,
    x='process_step',
    order=['start','step_1','step_2','step_3','confirm']
)
# Out:
# <Axes: xlabel='process_step', ylabel='count'>

# %%
from IPython.display import display

datasets = {
    "Demographics Data": df_demo,
    "Web Activity Data": df_web,
    "Experiment Grouping": df_experiment
}

def quick_inspeccion(df_dict):
    for nom, df in df_dict.items():
        print(f"\n{'='*10} {nom} {'='*10}")
        display(df.head())
        print(f"Dimensions: {df.shape}")

quick_inspeccion(datasets)
# Out:
# ========== Demographics Data ==========
#    client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0     836976             6.0              73.0      60.5     U        2.0
# 1    2304905             7.0              94.0      58.0     U        2.0
# 2    1439522             5.0              64.0      32.0     U        2.0
# 3    1562045            16.0             198.0      49.0     M        2.0
# 4    5126305            12.0             145.0      33.0     F        2.0
#
#          bal  calls_6_mnth  logons_6_mnth
# 0   45105.30           6.0            9.0
# 1  110860.30           6.0            9.0
# 2   52467.79           6.0            9.0
# 3   67454.65           3.0            6.0
# 4  103671.75           0.0            3.0
# Dimensions: (70609, 9)
#
# ========== Web Activity Data ==========
#    client_id            visitor_id                      visit_id process_step  \
# 0    9988021  580560515_7732621733  781255054_21935453173_531117       step_3
# ...

# %%
df_web.value_counts()
# Out:
# client_id  visitor_id             visit_id                      process_step  date_time
# 4859191    397211853_42468972771  124456641_38829817188_899341  start         2017-05-02 10:22:34    16
# 6563017    331858314_84978788510  943834869_97656130275_821170  start         2017-05-02 10:58:27    16
# 1584764    791516224_84593727364  169179906_69198539344_572701  start         2017-05-02 10:24:54    16
# 5380759    943775131_42929916546  694918984_92465751580_342876  start         2017-05-02 10:17:46    16
#                                                                               2017-05-02 10:21:00    16
#                                                                                                      ..
# 3391934    331050013_92494243154  109044768_71320897554_448227  confirm       2017-05-14 19:46:25     1
#                                                                 start         2017-05-14 19:43:07     1
# ...

# %%
df_web = df_web.drop_duplicates()


print(f"sin duplicados: {df_web.shape}")
# Out:
# sin duplicados: (744641, 5)

# %%
 df_web.value_counts()
# Out:
# client_id  visitor_id             visit_id                      process_step  date_time
# 169        201385055_71273495308  749567106_99161211863_557568  confirm       2017-04-12 20:23:09    1
# 6678462    668267137_53206073864  784193331_11468116125_624551  step_1        2017-06-16 10:27:35    1
#                                                                 step_3        2017-06-16 10:29:41    1
# 6678497    94339081_38077987588   898789343_95163196145_748820  start         2017-05-29 09:22:06    1
#                                                                               2017-05-29 09:26:34    1
#                                                                                                     ..
# 3370612    707636539_95215234471  261262795_36332122579_943155  step_1        2017-03-29 12:00:28    1
#                                                                 step_2        2017-03-29 12:01:08    1
# ...

# %%
print(df_web['process_step'].value_counts())
# Out:
# process_step
# start      234999
# step_1     162797
# step_2     132750
# step_3     111589
# confirm    102506
# Name: count, dtype: int64

# %%
df_web_exp = pd.merge(df_web, df_experiment, on='client_id', how='inner')

print(df_web_exp.groupby('Variation')['process_step'].value_counts())
# Out:
# Variation  process_step
# Control    start           45380
#            step_1          29544
#            step_2          25773
#            step_3          22503
#            confirm         17336
# Test       start           55773
#            step_1          38666
#            step_2          30899
#            step_3          25761
#            confirm         25600
# Name: count, dtype: int64

# %%
df_experiment.value_counts()
# Out:
# client_id  Variation
# 555        Test         1
# 6670730    Control      1
# 6670895    Test         1
# 6671189    Test         1
# 6671416    Control      1
#                        ..
# 3357578    Control      1
# 3357999    Control      1
# 3358285    Test         1
# 3358700    Test         1
# 9999832    Test         1
# Name: count, Length: 50500, dtype: int64

# %%
df_web_exp = pd.merge(df_web, df_experiment, on='client_id', how='inner')

# %%
df_web_exp.head(120-140)
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 443872     104557  964403920_33362996723   130036090_50724060621_44337
# 443873     104557  964403920_33362996723   130036090_50724060621_44337
# 443874     104557  964403920_33362996723   130036090_50724060621_44337
# 443875     104557  964403920_33362996723   130036090_50724060621_44337
# 443876    4899619  385002924_58383762926  689751326_42398762507_533801
#
#        process_step            date_time Variation
# 0            step_3  2017-04-17 15:27:07      Test
# ...

# %%
df_counts = df_web_exp.groupby(['Variation', 'visit_id', 'process_step']).size().reset_index(name='step_count')

confusio_mitjana = df_counts.groupby('Variation')['step_count'].mean()
print("Media de repeticiones por paso (más alt = máss confusión):")
print(confusio_mitjana)
# Out:
# Media de repeticiones por paso (más alt = máss confusión):
# Variation
# Control    1.290008
# Test       1.360667
# Name: step_count, dtype: float64

# %%
df_web_exp = df_web_exp.sort_values(['visit_id', 'date_time'])

df_web_exp['prev_step'] = df_web_exp.groupby('visit_id')['process_step'].shift(1)

def is_backtracking(row):
    steps_order = {'start': 0, 'step_1': 1, 'step_2': 2, 'step_3': 3, 'confirm': 4}
    if pd.isna(row['prev_step']): return False
    return steps_order.get(row['process_step'], 0) < steps_order.get(row['prev_step'], 0)

df_web_exp['goes_back'] = df_web_exp.apply(is_backtracking, axis=1)

backtrack_rate = df_web_exp.groupby('Variation')['goes_back'].mean() * 100
print(f"porcentaje de clics para atràs en steps':\n{backtrack_rate}")
# Out:
# porcentaje de clics para atràs en steps':
# Variation
# Control    6.935589
# Test       9.271133
# Name: goes_back, dtype: float64

# %%
total_usuarios_grupo = df_web_exp.groupby('Variation')['client_id'].nunique()
confirmacion_por_grupo = df_web_exp[df_web_exp['process_step'] == 'confirm'].groupby('Variation')['client_id'].nunique()
print(confirmacion_por_grupo)
# Out:
# Variation
# Control    15434
# Test       18687
# Name: client_id, dtype: int64

# %%
confirmacion_rate = (confirmacion_por_grupo / total_usuarios_grupo) * 100
print(confirmacion_rate)
# Out:
# Variation
# Control    65.587285
# Test       69.293236
# Name: client_id, dtype: float64

# %%
df_web_exp['date_time'] = pd.to_datetime(df_web_exp['date_time'])

df_web_exp = df_web_exp.sort_values(['visit_id', 'date_time'])

df_web_exp['time_diff'] = df_web_exp.groupby('visit_id')['date_time'].diff().shift(-1)

df_web_exp['time_diff_seconds'] = df_web_exp['time_diff'].dt.total_seconds()

df_time = df_web_exp[(df_web_exp['time_diff_seconds'] > 0) & (df_web_exp['time_diff_seconds'] < 3600)].copy()

print(f"Tiempo medio por paso")
print(df_time.groupby(['Variation', 'process_step'])['time_diff_seconds'].mean())
# Out:
# Tiempo medio por paso
# Variation  process_step
# Control    confirm         187.860154
#            start            64.602821
#            step_1           49.382461
#            step_2           91.255259
#            step_3          137.087360
# Test       confirm         241.602176
#            start            59.921775
#            step_1           60.163995
#            step_2           88.640853
#            step_3          128.652666
# Name: time_diff_seconds, dtype: float64

# %%
funnel_data = df_web_exp.groupby(['Variation', 'process_step'])['client_id'].nunique().unstack()

ordre_pas = ['start', 'step_1', 'step_2', 'step_3', 'confirm']
funnel_data = funnel_data[ordre_pas]

print("usuarios únicos por paso")
print(funnel_data)
# Out:
# usuarios únicos por paso
# process_step  start  step_1  step_2  step_3  confirm
# Variation
# Control       23397   20152   18650   17422    15434
# Test          26679   24267   22258   20881    18687

# %%
funnel_retention = funnel_data.div(funnel_data['start'], axis=0) * 100

print("Rate de retención")
print(funnel_retention.round(2))
# Out:
# Rate de retención
# process_step  start  step_1  step_2  step_3  confirm
# Variation
# Control       100.0   86.13   79.71   74.46    65.97
# Test          100.0   90.96   83.43   78.27    70.04

# %%
df_final = pd.merge(
    df_web_exp,
    df_demo,
    on='client_id',
    how='left'
)

# %%
df_final.head()
# Out:
#    client_id             visitor_id                      visit_id  \
# 0    3561384   451664975_1722933822  100012776_37918976071_457913
# 1    3561384   451664975_1722933822  100012776_37918976071_457913
# 2    7338123  612065484_94198474375   100019538_17884295066_43909
# 3    7338123  612065484_94198474375   100019538_17884295066_43909
# 4    7338123  612065484_94198474375   100019538_17884295066_43909
#
#   process_step           date_time Variation prev_step  goes_back  \
# 0      confirm 2017-04-26 13:22:17      Test       NaN      False
# 1      confirm 2017-04-26 13:23:09      Test   confirm      False
# 2        start 2017-04-09 16:20:56      Test       NaN      False
# 3       step_1 2017-04-09 16:21:12      Test     start      False
# 4       step_2 2017-04-09 16:21:21      Test    step_1      False
#
#         time_diff  time_diff_seconds  clnt_tenure_yr  clnt_tenure_mnth  \
# 0 0 days 00:00:52               52.0             4.0              56.0
# ...

# %%
df_final.shape
# Out:
# (443897, 18)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443897 entries, 0 to 443896
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   client_id          443897 non-null  int64
#  1   visitor_id         443897 non-null  object
#  2   visit_id           443897 non-null  object
#  3   process_step       443897 non-null  object
#  4   date_time          443897 non-null  datetime64[ns]
#  5   Variation          317235 non-null  object
#  6   prev_step          347124 non-null  object
#  7   goes_back          443897 non-null  bool
#  8   time_diff          347124 non-null  timedelta64[ns]
#  9   time_diff_seconds  347124 non-null  float64
#  10  clnt_tenure_yr     443784 non-null  float64
#  11  clnt_tenure_mnth   443784 non-null  float64
#  12  clnt_age           443772 non-null  float64
#  13  gendr              443784 non-null  object
#  14  num_accts          443784 non-null  float64
# ...

# %% [markdown]
# # EDAD MEDIA POR GRUPO

# %%
df_final.groupby('Variation')['clnt_age'].mean()
# Out:
# Variation
# Control    48.284478
# Test       48.722216
# Name: clnt_age, dtype: float64

# %% [markdown]
# # BALANCE MEDIO

# %%
df_final.groupby('Variation')['bal'].mean()
# Out:
# Variation
# Control    158880.611361
# Test       162323.086001
# Name: bal, dtype: float64

# %% [markdown]
# # EDAD DE QUIENES COMPLETAN EL PROCESO

# %%
df_confirm = df_final[df_final['process_step'] == 'confirm']

df_confirm.groupby('Variation')['clnt_age'].mean()
# Out:
# Variation
# Control    47.711639
# Test       47.971321
# Name: clnt_age, dtype: float64
